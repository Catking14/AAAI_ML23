# %%
import csv
path = './data/mega_train.csv'
indexes = []
texts = []
authors = []
with open(path, newline='', encoding='utf-8') as csvfile:
    csvreader = csv.DictReader(csvfile)
    for row in csvreader:
        indexes.append(row['index'])
        texts.append(row['text'])
        authors.append(row['Author'])
import re
documents = []
cur_author  = authors[0]
j = 0
for i in range(50):
    author = []
    
    while  j<4000 and authors[j] == cur_author:
        text = texts[j].lower()
        text_no_punctuation_digits = re.sub(r'[^\w\s]', '', text)
        article = re.sub(r'\d+', '', text_no_punctuation_digits).split()
        author.append(article)
        j += 1
    if j < 4000:
        cur_author = authors[j]
    documents.append(author)
print(len(documents))
# Out:
# 50

# %% [markdown]
# ### Compute IDF for words in all articles

# %%
from math import log
from collections import Counter

def compute_idf(documents):
    N = 0
    for i in range(len(documents)):
        N += len(documents[i])
    
    idf_dict = {}

    df = Counter()
    for author in documents:
        for document in author:
            for word in set(document):
                df[word] += 1

    # Calculate IDF for each word
    for word, count in df.items():
        if log(N/ count) < 1 :
            idf_dict[word] = 0
        else:
            idf_dict[word] = 1

    return idf_dict

idf_scores = compute_idf(documents)
print(idf_scores)  # Display the IDF scores for each word
# Out:
# {'commerce': 1, 'after': 0, 'loans': 1, 'including': 1, 'loophole': 1, 'and': 0, 'but': 0, 'administrations': 1, 'of': 0, 'maintained': 1, 'covered': 1, 'republican': 1, 'any': 1, 'are': 0, 'democratic': 1, 'attempts': 1, 'chose': 1, 'could': 0, 'worlds': 1, 'concerns': 1, 'how': 1, 'at': 0, 'significant': 1, 'monday': 1, 'pending': 1, 'banking': 1, 'mixing': 1, 'association': 1, 'portions': 1, 'electronic': 1, 'ducked': 1, 'dynamic': 1, 'limitation': 1, 'reform': 1, 'financial': 1, 'most': 1, 'institution': 1, 'companies': 1, 'instead': 1, 'hearing': 1, 'labor': 1, 'unveiled': 1, 'that': 0, 'irrelevent': 1, 'deposits': 1, 'proponents': 1, 'big': 1, 'decade': 1, 'overhauling': 1, 'suggest': 1, 'capitol': 1, 'marge': 1, 'limited': 1, 'one': 0, 'permitted': 1, 'or': 0, 'firms': 1, 'referred': 1, 'tuesday': 1, 'foremost': 1, 'chairpersons': 1, 'hard': 1, 'savings': 1, 'loan': 1, 'undermine': 1, 'socalled': 1, 'largest': 1, 'clinton': 1, 'what': 1, 'for': 0, 'issued': 1, 'going': 1, 'firm': 1, 'prohibition': 1, 'derive': 1, 'have': 0, 'secretary': 1, 'access': 1, 'by': 0, 'jersey': 1, 'house': 1, 'current': 1, 'legislation': 1, 'republicans': 1, 'would': 0, 'institutions': 1, 'years': 0, 'out': 0, 'approach': 1, 'operating': 1, 'risks': 1, 'their': 0, 'ranged': 1, 'economic': 1, 'say': 1, 'its': 0, 'administration': 1, 'laws': 1, 'accepts': 1, 'committee': 1, 'so': 1, 'measured': 1, 'insurance': 1, 'richard': 1, 'opposite': 1, 'basket': 1, 'who': 0, 'criticism': 1, 'bakers': 1, 'hill': 1, 'think': 1, 'mergers': 1, 'national': 1, 'outlined': 1, 'exception': 1, 'focus': 1, 'allow': 1, 'scrap': 1, 'services': 1, 'banks': 1, 'glasssteagall': 1, 'with': 0, 'we': 0, 'charters': 1, 'passed': 1, 'has': 0, 'those': 1, 'deposit': 1, 'legal': 1, 'some': 0, 'fund': 1, 'choice': 1, 'limitations': 1, 'combining': 1, 'draw': 1, 'merged': 1, 'further': 1, 'opponents': 1, 'led': 1, 'nonfinancial': 1, 'over': 0, 'not': 0, 'staffers': 1, 'take': 1, 'signers': 1, 'be': 0, 'way': 1, 'raise': 1, 'goes': 1, 'sidetrack': 1, 'bank': 1, 'thrift': 1, 'roukema': 1, 'robert': 1, 'plan': 1, 'to': 0, 'acts': 1, 'tuesdays': 1, 'month': 1, 'against': 1, 'contain': 1, 'however': 1, 'more': 0, 'payment': 1, 'strongest': 1, 'announced': 1, 'unlimited': 1, 'industrys': 1, 'contentious': 1, 'holding': 1, 'success': 1, 'will': 0, 'federal': 1, 'activity': 1, 'the': 0, 'alternative': 1, 'legislators': 1, 'examine': 1, 'directed': 1, 'commercial': 1, 'under': 1, 'gross': 1, 'different': 1, 'allowing': 1, 'consumer': 1, 'alternatives': 1, 'likely': 1, 'recapitalize': 1, 'left': 1, 'congress': 1, 'no': 0, 'jim': 1, 'is': 0, 'from': 0, 'came': 1, 'year': 0, 'lawmakers': 1, 'even': 1, 'without': 1, 'louisiana': 1, 'bankers': 1, 'other': 0, 'leach': 1, 'staffer': 1, 'rules': 1, 'treasury': 1, 'steer': 1, 'last': 0, 'revenues': 1, 'walk': 1, 'wholesale': 1, 'excluding': 1, 'system': 1, 'structured': 1, 'respectively': 1, 'only': 1, 'on': 0, 'bills': 1, 'asset': 1, 'render': 1, 'as': 0, 'continue': 1, 'rubin': 1, 'debated': 1, 'than': 0, 'subcommittee': 1, 'size': 1, 'explain': 1, 'fine': 1, 'line': 1, 'agriculture': 1, 'percentage': 1, 'iowa': 1, 'was': 0, 'chairman': 1, 'small': 1, 'he': 0, 'groups': 1, 'loopholes': 1, 'notion': 1, 'report': 1, 'several': 1, 'own': 1, 'needs': 1, 'baker': 1, 'this': 0, 'along': 1, 'proposal': 1, 'try': 1, 'antiquated': 1, 'second': 1, 'enormous': 1, 'two': 0, 'establish': 1, 'analysts': 0, 'reserves': 1, 'industries': 1, 'tack': 1, 'combine': 1, 'offered': 1, 'said': 0, 'a': 0, 'new': 0, 'statement': 1, 'traditionally': 1, 'us': 0, 'also': 0, 'may': 1, 'separation': 1, 'issue': 1, 'strongly': 1, 'able': 1, 'voted': 1, 'susan': 1, 'barriers': 1, 'want': 1, 'away': 1, 'steve': 1, 'next': 1, 'modernization': 1, 'change': 1, 'market': 0, 'constructive': 1, 'hope': 1, 'past': 1, 'vote': 1, 'restated': 1, 'rule': 1, 'president': 1, 'move': 1, 'corporate': 1, 'adopted': 1, 'representatives': 1, 'position': 1, 'separating': 1, 'paper': 1, 'according' ...

# %% [markdown]
# ### Compute IDF for a single author

# %%
from math import log
from collections import Counter

def compute_idf_for_author (author_index, documents):
    idf_dict = {}
    df = Counter()
    index = 1
    for author in documents:
        idf_flag = Counter()
        for document in author:
            for word in set(document):
                if index == author_index:
                    if(idf_flag[word] == 0):
                        df[word] += 1
                        idf_flag[word] += 1

                else:
                    if(idf_flag[word] == 0):
                        df[word] += 50
                        idf_flag[word] += 1
                    
        index+=1
    for word, count in df.items():
        idf_dict[word] = max(0, log(50 / (count)))  

    return idf_dict
idf_socres_author = []
for i in range(50):
    idf_t = compute_idf_for_author(i+1, documents)
    idf_socres_author.append(idf_t)
    
print(len(idf_socres_author))
# Out:
# 50

# %% [markdown]
# ### Compute TF for each word within articles with same author

# %%
from math import log
from collections import Counter

def compute_author_frequent_word_level (author_index, documents):
    
    tf_dict = {}

    # Count the number of documents that contain each word
    df = Counter()
    all_count = 0

    for document in documents[author_index - 1]:
        for word in document:
            df[word] += 1
        
        all_count += len(document)


    # Calculate TF for each word
    for word, count in df.items():
        tf_dict[word] = max(0, (count - 3) / all_count * 100)     # 3 is a threshold

    return tf_dict

# Example usage
a_feq = []
for i in range(50):
    tf_t = compute_author_frequent_word_level(i+1, documents)
    a_feq.append(tf_t)
    
print(a_feq[0])
# Out:
# {'treasury': 0.07307962972987604, 'secretary': 0.05954636496508418, 'robert': 0.037893141341417205, 'rubin': 0.08931954744762627, 'goes': 0, 'to': 2.928598495100958, 'capitol': 0.013533264764791858, 'hill': 0.010826611811833486, 'on': 0.9256753099117631, 'tuesday': 0.05413305905916743, 'further': 0.027066529529583716, 'explain': 0, 'the': 7.1455637958101015, 'clinton': 0.15157256536566882, 'administrations': 0.05954636496508418, 'bank': 0.1813457478482109, 'reform': 0.094732853353543, 'plan': 0.28149190710767064, 'but': 0.5440372435446327, 'lawmakers': 0.04601310020029232, 'are': 0.40599794294375574, 'likely': 0.05954636496508418, 'focus': 0.013533264764791858, 'foremost': 0, 'what': 0.07849293563579278, 'left': 0.005413305905916743, 'out': 0.12179938288312672, 'proposal': 0.1245060358360851, 'along': 0.01623991771775023, 'with': 0.6035836085097169, 'several': 0.05954636496508418, 'pending': 0.0027066529529583714, 'bills': 0.07578628268283441, 'would': 0.5494505494505495, 'scrap': 0.0027066529529583714, 'glasssteagall': 0.040599794294375574, 'acts': 0, 'separation': 0, 'of': 2.831158988794457, 'banking': 0.2571320305310453, 'from': 0.47907757267363177, 'other': 0.23547880690737832, 'financial': 0.22465219509554485, 'services': 0.1055594651653765, 'contentious': 0.005413305905916743, 'issue': 0.10285281221241813, 'going': 0.03247983543550046, 'and': 2.2086288096140314, 'allowing': 0.1245060358360851, 'banks': 0.5007307962972988, 'combine': 0.03247983543550046, 'commercial': 0.1245060358360851, 'firms': 0.19487901261300275, 'however': 0.02165322362366697, 'administration': 0.2381854598603367, 'ducked': 0.0027066529529583714, 'instead': 0.040599794294375574, 'unveiled': 0.018946570670708603, 'by': 0.6658366264277594, 'may': 0.11909272993016835, 'offered': 0.010826611811833486, 'two': 0.14074595355383532, 'alternatives': 0.005413305905916743, 'hard': 0.008119958858875115, 'choice': 0, 'congress': 0.32209170140204624, 'we': 0.2652519893899204, 'think': 0.037893141341417205, 'needs': 0.037893141341417205, 'be': 0.7280896443458019, 'debated': 0.005413305905916743, 'said': 1.404752882585395, 'as': 0.5332106317327993, 'he': 0.23277215395441997, 'announced': 0.040599794294375574, 'has': 0.2652519893899204, 'overhauling': 0, 'antiquated': 0.0027066529529583714, 'us': 0.2300655010014616, 'laws': 0.11638607697720998, 'for': 0.8607156390407622, 'more': 0.2544253775780869, 'than': 0.11367942402425162, 'a': 2.2167487684729066, 'decade': 0.008119958858875115, 'without': 0.08119958858875115, 'success': 0, 'some': 0.2544253775780869, 'analysts': 0.005413305905916743, 'suggest': 0.010826611811833486, 'commerce': 0.20570562442483625, 'will': 0.4574243490499648, 'sidetrack': 0, 'this': 0.30043847777837923, 'years': 0.07037297677691766, 'attempts': 0, 'at': 0.41953120770854757, 'tuesdays': 0, 'house': 0.1245060358360851, 'committee': 0.1921723596600444, 'hearing': 0.05683971201212581, 'opponents': 0.010826611811833486, 'mixing': 0.05413305905916743, 'led': 0.008119958858875115, 'chairman': 0.10285281221241813, 'iowa': 0.02165322362366697, 'republican': 0.07849293563579278, 'jim': 0.02165322362366697, 'leach': 0.04601310020029232, 'try': 0.013533264764791858, 'steer': 0, 'examine': 0, 'risks': 0.008119958858875115, 'unlimited': 0.0027066529529583714, 'mergers': 0, 'proponents': 0, 'including': 0.07037297677691766, 'subcommittee': 0.04330644724733394, 'chairpersons': 0, 'marge': 0.008119958858875115, 'roukema': 0.008119958858875115, 'richard': 0, 'baker': 0.0027066529529583714, 'republicans': 0, 'new': 0.3329183132138797, 'jersey': 0.005413305905916743, 'louisiana': 0, 'respectively': 0, 'take': 0.03518648838845883, 'opposite': 0, 'tack': 0, 'under': 0.2598386834840037, 'one': 0.2381854598603367, 'alternative': 0, 'outlined': 0.008119958858875115, 'last': 0.189465706707086, 'month': 0.05683971201212581, 'limited': 0.04330644724733394, 'permitted': 0.027066529529583716, 'excluding': 0, 'or': 0.3545715368375467, 'so': 0.040599794294375574, 'largest': 0. ...

# %% [markdown]
# ### Compute TF-IDF and sort all words

# %%
word_list = []
for i in range(50):
    temp = {}
    for word in a_feq[i]:
        temp[word] = idf_scores[word] * idf_socres_author[i][word] * a_feq[i][word]
    word_list.append(temp)

def sort_and_filter_dicts(word_list):
    new_word_list = []
    for d in word_list:
        filtered_dict = {k: v for k, v in d.items() if v > 0}   # remove objects with nonpositive weight
        sorted_dict = dict(sorted(filtered_dict.items(), key=lambda item: item[1],reverse = True))
        new_word_list.append(sorted_dict)
    return new_word_list
word_list = sort_and_filter_dicts(word_list)

tfidf_count = []
for i in word_list:
    tfidf_count.append(len(i))

mx = max(tfidf_count)
author_selected = tfidf_count.index(mx)

print(author_selected)
# Out:
# 20

# %%
with open("./data/tfidf-words-20.csv", "w") as fd:
    writer = csv.writer(fd)
    
    for key in word_list[author_selected]:
        writer.writerow([key])

# %% [markdown]
# ### Compute TF-IDF to find words to replace for each article
#
# This part is used on testing (validation) datasets.

# %%
import csv
path = './data/mega_test.csv'
indexes = []
texts = []
authors = []
with open(path, newline='', encoding='utf-8') as csvfile:
    csvreader = csv.DictReader(csvfile)
    for row in csvreader:
        indexes.append(row['index'])
        texts.append(row['text'])
        authors.append(row['Author'])
import re
documents = []
cur_author  = authors[0]
j = 0
for i in range(50):
    author = []
    
    while  j < 1000 and authors[j] == cur_author:
        text = texts[j].lower()
        text_no_punctuation_digits = re.sub(r'[^\w\s]', '', text)
        article = re.sub(r'\d+', '', text_no_punctuation_digits).split()
        author.append(article)
        j += 1
    if j < 1000:
        cur_author = authors[j]
    documents.append(author)
print(len(documents))

# %% [markdown]
# #### Compute TF for an article

# %%
from math import log
from collections import Counter

def compute_tf_in_single_article (document):
    
    tf_dict = {}

    # Count the number of frequency in an article
    df = Counter()
    all_count = len(document)

    for word in document:
        df[word] += 1

    # Calculate TF for each word
    for word, count in df.items():
        tf_dict[word] = max(0, (count - 3) / all_count)     # 3 is a threshold

    return tf_dict

# Example usage
a_feq = []
for au in range(50):
    for document in documents[au]:
        a_feq.append(compute_tf_in_single_article(document))
    
print(a_feq[0])

# %% [markdown]
# #### Compute IDF for a single article

# %%
from math import log
from collections import Counter

def compute_idf_in_single_article (article, documents):
    
    idf_dict = {}

    # Count the number of frequency in an article
    df = Counter()
    all_count = 1000

    for word in article:
        for document in documents:
            if word in document:    # exist in some article
                df[word] += 1

    # Calculate TF for each word
    for word, count in df.items():
        idf_dict[word] = math.log(all_count / (count + 1))     # prevent division by zero

    return idf_dict
